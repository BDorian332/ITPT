# %%
import sys
print(sys.executable)
# Out:
# C:\Users\dorian\AppData\Local\pypoetry\Cache\virtualenvs\itpt-lW0Igsa9-py3.13\Scripts\python.exe

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr

# %%
img_path = "dev/_datasets/Tree_PNG_50tips_NOISE_1/images/Tree_50_1.png"
image = cv2.imread(img_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
reader = easyocr.Reader(["en"], gpu=False)
results = reader.readtext(image)

print(f"Nombre de textes détectés : {len(results)}")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# C:\Users\dorian\AppData\Local\pypoetry\Cache\virtualenvs\itpt-lW0Igsa9-py3.13\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Nombre de textes détectés : 70

# %% [markdown]
# ![EasyOCR image](attachment:image.png)

# %%
plt.figure(figsize=(12,12))
img_show = image.copy()
for bbox, text, score in results:
    x1, y1 = bbox[0]
    x2, y2 = bbox[2]
    cv2.rectangle(img_show, (int(x1), int(y1)), (int(x2), int(y2)), (255,0,0), 2)
    cv2.putText(img_show, text, (int(x1), int(y1)-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 1)
plt.imshow(img_show)
plt.axis('off')
plt.show()

# %%
filtered_text_boxes = [
    {"bbox": bbox, "text": text, "score": score}
    for bbox, text, score in results
    if not any(char.isdigit() for char in text)
]

for i, entry in enumerate(filtered_text_boxes[:20], 1):
    print(f"{i}: text='{entry['text']}', score={entry['score']:.2f}, bbox={entry['bbox']}")
# Out:
# 1: text='kltpib', score=1.00, bbox=[[np.int32(1175), np.int32(202)], [np.int32(1258), np.int32(202)], [np.int32(1258), np.int32(241)], [np.int32(1175), np.int32(241)]]
# 2: text='xthslq', score=1.00, bbox=[[np.int32(1177), np.int32(235)], [np.int32(1265), np.int32(235)], [np.int32(1265), np.int32(271)], [np.int32(1177), np.int32(271)]]
# 3: text='ftSXcv', score=0.49, bbox=[[np.int32(1176), np.int32(272)], [np.int32(1264), np.int32(272)], [np.int32(1264), np.int32(302)], [np.int32(1176), np.int32(302)]]
# 4: text='Iwotrm', score=0.98, bbox=[[np.int32(1178), np.int32(300)], [np.int32(1274), np.int32(300)], [np.int32(1274), np.int32(332)], [np.int32(1178), np.int32(332)]]
# 5: text='emvljn', score=1.00, bbox=[[np.int32(1179), np.int32(327)], [np.int32(1273), np.int32(327)], [np.int32(1273), np.int32(363)], [np.int32(1179), np.int32(363)]]
# 6: text='gyqbyz', score=0.99, bbox=[[np.int32(1173), np.int32(354)], [np.int32(1284), np.int32(354)], [np.int32(1284), np.int32(402)], [np.int32(1173), np.int32(402)]]
# 7: text='zluosx', score=0.99, bbox=[[np.int32(1178), np.int32(396)], [np.int32(1272), np.int32(396)], [np.int32(1272), np.int32(426)], [np.int32(1178), np.int32(426)]]
# 8: text='roisyb', score=1.00, bbox=[[np.int32(1177), np.int32(421)], [np.int32(1267), np.int32(421)], [np.int32(1267), np.int32(457)], [np.int32(1177), np.int32(457)]]
# 9: text='ufngte', score=1.00, bbox=[[np.int32(1179), np.int32(451)], [np.int32(1269), np.int32(451)], [np.int32(1269), np.int32(489)], [np.int32(1179), np.int32(489)]]
# 10: text='Ijvdfk', score=0.53, bbox=[[np.int32(1175), np.int32(479)], [np.int32(1258), np.int32(479)], [np.int32(1258), np.int32(521)], [np.int32(1175), np.int32(521)]]
# 11: text='sshsdtr', score=0.64, bbox=[[np.int32(1177), np.int32(512)], [np.int32(1272), np.int32(512)], [np.int32(1272), np.int32(551)], [np.int32(1177), np.int32(551)]]
# 12: text='dwrsxc', score=0.97, bbox=[[np.int32(1182), np.int32(548)], [np.int32(1280), np.int32(548)], [np.int32(1280), np.int32(580)], [np.int32(1182), np.int32(580)]]
# 13: text='wjgggb', score=0.91, bbox=[[np.int32(1178), np.int32(572)], [np.int32(1282), np.int32(572)], [np.int32(1282), np.int32(614)], [np.int32(1178), np.int32(614)]]
# 14: text='awvptr', score=1.00, bbox=[[np.int32(1179), np.int32(605)], [np.int32(1277), np.int32(605)], [np.int32(1277), np.int32(641)], [np.int32(1179), np.int32(641)]]
# 15: text='hxphrf', score=0.62, bbox=[[np.int32(1177), np.int32(632)], [np.int32(1275), np.int32(632)], [np.int32(1275), np.int32(676)], [np.int32(1177), np.int32(676)]]
# 16: text='vrkkbi', score=0.99, bbox=[[np.int32(1177), np.int32(667)], [np.int32(1268), np.int32(667)], [np.int32(1268), np.int32(705)], [np.int32(1177), np.int32(705)]]
# 17: text='ivcuqv', score=1.00, bbox=[[np.int32(1178), np.int32(700)], [np.int32(1272), np.int32(700)], [np.int32(1272), np.int32(732)], [np.int32(1178), np.int32(732)]]
# 18: text='niituu _', score=0.64, bbox=[[np.int32(1177), np.int32(729)], [np.int32(1260), np.int32(729)], [np.int32(1260), np.int32(767)], [np.int32(1177), np.int32(767)]]
# 19: text='btimuj', score=1.00, bbox=[[np.int32(1177), np.int32(759)], [np.int32(1269), np.int32(759)], [np.int32(1269), np.int32(795)], [np.int32(1177), np.int32(795)]]
# 20: text='wjviee', score=0.78, bbox=[[np.int32(1177), np.int32(785)], [np.int32(1270), np.int32(785)], [np.int32(1270), np.int32(829)], [np.int32(1177), np.int32(829)]]
